# %%
# from google.colab import drive # driveを接続
# drive.mount('/content/gdrive')
# %cd /content/gdrive/My Drive/研究室/work_dir/ijcars19-master/src

# %%
# !pip install -r requirements.txt
# !pip install h5py==2.10.0
# !pip install tensorflow==1.14.0
# !pip install tensorflow-gpu==1.14.0
# !pip install keras==2.3.1

# %%
# %run oil_classification.py
# Out:
# dimensions_to_use=21
# trial_out_num:7_Out
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, None, 2)]    0           []
#
#  input_2 (InputLayer)           [(None, None, 3)]    0           []
#
#  input_3 (InputLayer)           [(None, None, 3)]    0           []
#
#  input_4 (InputLayer)           [(None, None, 1)]    0           []
#
#  input_5 (InputLayer)           [(None, None, 3)]    0           []
#
#  input_6 (InputLayer)           [(None, None, 3)]    0           []
#
#  input_7 (InputLayer)           [(None, None, 6)]    0           []
#
#  conv1d (Conv1D)                (None, None, 8)      56          ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)              (None, None, 8)      80          ['input_2[0][0]']
#
# ...

# %%
# %run oil_classification.py # dim=21, data=full_length
# Out:
# dimensions_to_use=21
# trial_out_num:7_Out
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, None, 2)]    0           []
#
#  input_2 (InputLayer)           [(None, None, 3)]    0           []
#
#  input_3 (InputLayer)           [(None, None, 3)]    0           []
#
#  input_4 (InputLayer)           [(None, None, 1)]    0           []
#
#  input_5 (InputLayer)           [(None, None, 3)]    0           []
#
#  input_6 (InputLayer)           [(None, None, 3)]    0           []
#
#  input_7 (InputLayer)           [(None, None, 6)]    0           []
#
#  conv1d (Conv1D)                (None, None, 8)      56          ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)              (None, None, 8)      80          ['input_2[0][0]']
#
# ...

# %%
# %run oil_classification.py cas # dim=21, data=full_length
# Out:
# dimensions_to_use=21
# subject:A try_num:0
# true_label:E
# predicted_label:E
# subject:A try_num:1
# true_label:E
# predicted_label:E
# subject:A try_num:2
# true_label:E
# predicted_label:E
# subject:A try_num:3
# true_label:E
# predicted_label:E
# subject:A try_num:4
# true_label:E
# predicted_label:E
# subject:A try_num:5
# true_label:E
# predicted_label:E
# subject:A try_num:6
# true_label:E
# predicted_label:E
# subject:A try_num:7
# true_label:E
# predicted_label:E
# subject:A try_num:8
# true_label:E
# predicted_label:E
# subject:A try_num:9
# true_label:E
# predicted_label:E
# subject:D try_num:0
# true_label:N
# predicted_label:N
# subject:D try_num:1
# true_label:N
# predicted_label:N
# subject:D try_num:2
# true_label:N
# predicted_label:N
# subject:D try_num:3
# true_label:N
# predicted_label:N
# subject:D try_num:4
# true_label:N
# predicted_label:N
# subject:D try_num:5
# true_label:N
# predicted_label:N
# subject:D try_num:6
# true_label:N
# predicted_label:N
# ...

# %%
# %run oil_classification.py
# Out:
# dimensions_to_use=5
# trial_out_num:7_Out
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, None, 2)]    0           []
#
#  input_2 (InputLayer)           [(None, None, 3)]    0           []
#
#  conv1d (Conv1D)                (None, None, 8)      56          ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)              (None, None, 8)      80          ['input_2[0][0]']
#
#  activation (Activation)        (None, None, 8)      0           ['conv1d[0][0]']
#
#  activation_1 (Activation)      (None, None, 8)      0           ['conv1d_1[0][0]']
#
#  concatenate (Concatenate)      (None, None, 16)     0           ['activation[0][0]',
#                                                                   'activation_1[0][0]']
#
# ...

# %%
# %run oil_classification.py
# Out:
# dimensions_to_use=21
# trial_out_num:7_Out
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, None, 2)]    0           []
#
#  input_2 (InputLayer)           [(None, None, 3)]    0           []
#
#  input_3 (InputLayer)           [(None, None, 3)]    0           []
#
#  input_4 (InputLayer)           [(None, None, 1)]    0           []
#
#  input_5 (InputLayer)           [(None, None, 3)]    0           []
#
#  input_6 (InputLayer)           [(None, None, 3)]    0           []
#
#  input_7 (InputLayer)           [(None, None, 6)]    0           []
#
#  conv1d (Conv1D)                (None, None, 16)     112         ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)              (None, None, 16)     160         ['input_2[0][0]']
#
# ...
