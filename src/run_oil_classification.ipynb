# %%
# %run oil_classification.py
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='25' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       2.50% [25/1000 07:48<5:04:34]
#     </div>
#
#
#
#     <div>
#       <progress value='15' class='' max='54' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       27.78% [15/54 00:03<00:08]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...
